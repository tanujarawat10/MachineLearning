# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("C:\Tanuja\cars.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("C:\\Tanuja\\ads.csv")
import random
N=11
d=3
ads_selected=[]
numbers_of_rewards_1=[0]*d
numbers_of_rewards_0=[0]*d
total_rewads=0
for n in range (0,N):
    ad=0
    max_random=0
    for i in range (0,d):
        random_beta=random.betavariate(numbers_of_rewards_1[i]+1,numbers_of_rewards_0[i]+1)
        if random_beta>max_random:
            max_random=random_beta
            ad=i
    ads_selected.append(ad)
    reward=data.values[n,ad]
    if reward==1:
        numbers_of_rewards_1[ad]=numbers_of_rewards_1[ad]+1
    else:
        numbers_of_rewards_0[ad]=numbers_of_rewards_0[ad]+1
    total_rewards=total_reward+int(reward)
plt.hist(ads_selected)
plt.title("histogram of ads selection")
plt.xlabel('ads')
plt.ylabel('no. of timme an ad was selected')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv("C:\\Tanuja\\ads.csv")
import random
import math
N=11
d=3
ads_selected=[]
numbers_of_selections=[0]*d
numbers_of_rewards=[0]*d
total_reward=0
for n in range (0,N):
    ad=0
    max_upper_bound=0
    for i in range (0,d):
        if (numbers)
        random_beta=random.betavariate(numbers_of_rewards_1[i]+1,numbers_of_rewards_0[i]+1)
        if random_beta>max_random:
            max_random=random_beta
            ad=i
    ads_selected.append(ad)
    reward=data.values[n,ad]
    if reward==1:
        numbers_of_rewards_1[ad]=numbers_of_rewards_1[ad]+1
    else:
        numbers_of_rewards_0[ad]=numbers_of_rewards_0[ad]+1
    total_rewads=total_reward=int(reward)
    print(sum_of_rewards)
    print(total_reward)
plt.hist(ads_selected)
plt.title("histogram of ads selection")
plt.xlabel('ads')
plt.ylabel('no. of timme an ad was selected')
plt.show()
